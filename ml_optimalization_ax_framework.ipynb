# %% [markdown]
# # Optimalization using Ax (Adaptive Experimentation Platform)
#
# More info:
# - https://ax.dev/#quickstart
#
# How to install PyTorch (go to pytorch.org for instruction), e.g.:
# - pip3 install torch==1.5.0+cpu torchvision==0.6.0+cpu -f https://download.pytorch.org/whl/torch_stable.html
# - pip3 install ax-platform

# %% [markdown]
# # Quick start

# %%
from ax import optimize

best_parameters, best_values, experiment, model = optimize(
        parameters=[
          {
            "name": "x1",
            "type": "range",
            "bounds": [-10.0, 10.0],
          },
          {
            "name": "x2",
            "type": "range",
            "bounds": [-10.0, 10.0],
          },
        ],
        # Booth function
        evaluation_function=lambda p: (p["x1"] + 2*p["x2"] - 7)**2 + (2*p["x1"] + p["x2"] - 5)**2,
        minimize=True,
    )
# Out:
# [INFO 04-29 12:54:39] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+GPEI', steps=[Sobol for 5 arms, GPEI for subsequent arms], generated 0 arm(s) so far). Iterations after 5 will take longer to generate due to model-fitting.
# [INFO 04-29 12:54:39] ax.service.managed_loop: Started full optimization with 20 steps.
# [INFO 04-29 12:54:39] ax.service.managed_loop: Running optimization trial 1...
# [INFO 04-29 12:54:39] ax.service.managed_loop: Running optimization trial 2...
# [INFO 04-29 12:54:39] ax.service.managed_loop: Running optimization trial 3...
# [INFO 04-29 12:54:39] ax.service.managed_loop: Running optimization trial 4...
# [INFO 04-29 12:54:39] ax.service.managed_loop: Running optimization trial 5...
# [INFO 04-29 12:54:39] ax.service.managed_loop: Running optimization trial 6...
# [INFO 04-29 12:54:40] ax.service.managed_loop: Running optimization trial 7...
# [INFO 04-29 12:54:41] ax.service.managed_loop: Running optimization trial 8...
# [INFO 04-29 12:54:42] ax.service.managed_loop: Running optimization trial 9...
# [INFO 04-29 12:54:42] ax.service.managed_loop: Running optimization trial 10...
# [INFO 04-29 12:54:44] ax.service.managed_loop: Running optimization trial 11...
# [INFO 04-29 12:54:45] ax.service.managed_loop: Running optimization trial 12...
# [INFO 04-29 12:54:46] ax.service.managed_loop: Running optimization trial 13...
# [INFO 04-29 12:54:47] ax.service.managed_loop: Running optimization trial 14...
# [INFO 04-29 12:54:48] ax.service.managed_loop: Running optimization trial 15...
# [INFO 04-29 12:54:49] ax.service.managed_loop: Running optimization trial 16...
# [INFO 04-29 12:54:50] ax.service.managed_loop: Running optimization trial 17...
# [INFO 04-29 12:54:51] ax.service.managed_loop: Running optimization trial 18...
# [INFO 04-29 12:54:51] ax.service.managed_loop: Running optimization trial 19...
# [INFO 04-29 12:54:52] ax.service.managed_loop: Running optimization trial 20...

# %%
# true min is (1, 3)
print('Minimum found:', best_parameters)
# Out:
# Minimum found: {'x1': 1.0, 'x2': 1.0}

# %% [markdown]
# # Rosenbrock function minimalization

# %%
func_rosenbrock = lambda p: .5*(1 - p["x1"])**2 + (p["x2"] - p["x1"]**2)**2

best_parameters, best_values, experiment, model = optimize(
        parameters=[
          {
            "name": "x1",
            "type": "range",
            "bounds": [-2.0, 1.0],
          },
          {
            "name": "x2",
            "type": "range",
            "bounds": [-2.0, 1.0],
          },
        ],
        # Booth function
        evaluation_function=func_rosenbrock,
        minimize=True,
    )
# Out:
# [INFO 04-29 12:55:08] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+GPEI', steps=[Sobol for 5 arms, GPEI for subsequent arms], generated 0 arm(s) so far). Iterations after 5 will take longer to generate due to model-fitting.
# [INFO 04-29 12:55:08] ax.service.managed_loop: Started full optimization with 20 steps.
# [INFO 04-29 12:55:08] ax.service.managed_loop: Running optimization trial 1...
# [INFO 04-29 12:55:08] ax.service.managed_loop: Running optimization trial 2...
# [INFO 04-29 12:55:08] ax.service.managed_loop: Running optimization trial 3...
# [INFO 04-29 12:55:08] ax.service.managed_loop: Running optimization trial 4...
# [INFO 04-29 12:55:08] ax.service.managed_loop: Running optimization trial 5...
# [INFO 04-29 12:55:08] ax.service.managed_loop: Running optimization trial 6...
# [INFO 04-29 12:55:09] ax.service.managed_loop: Running optimization trial 7...
# [INFO 04-29 12:55:09] ax.service.managed_loop: Running optimization trial 8...
# [INFO 04-29 12:55:10] ax.service.managed_loop: Running optimization trial 9...
# [INFO 04-29 12:55:11] ax.service.managed_loop: Running optimization trial 10...
# [INFO 04-29 12:55:11] ax.service.managed_loop: Running optimization trial 11...
# [INFO 04-29 12:55:12] ax.service.managed_loop: Running optimization trial 12...
# [INFO 04-29 12:55:13] ax.service.managed_loop: Running optimization trial 13...
# [INFO 04-29 12:55:14] ax.service.managed_loop: Running optimization trial 14...
# [INFO 04-29 12:55:15] ax.service.managed_loop: Running optimization trial 15...
# [INFO 04-29 12:55:15] ax.service.managed_loop: Running optimization trial 16...
# c:\apps\python36\lib\site-packages\gpytorch\utils\cholesky.py:44: NumericalWarning:
#
# A not p.d., added jitter of 1e-08 to the diagonal
#
# [INFO 04-29 12:55:16] ax.service.managed_loop: Running optimization trial 17...
# [INFO 04-29 12:55:17] ax.service.managed_loop: Running optimization trial 18...
# [INFO 04-29 12:55:17] ax.service.managed_loop: Running optimization trial 19...
# [INFO 04-29 12:55:18] ax.service.managed_loop: Running optimization trial 20...

# %%
print('Minimum found:', best_parameters, ', values:', best_values)
# Out:
# Minimum found: {'x1': 1.0, 'x2': 1.0} , values: ({'objective': 2.2985151536758508e-05}, {'objective': {'objective': 3.0191322349031983e-06}})

# %%
# Results using other methods:
# Method: Nelder-Mead , success: True , minimum: 1.11527915993744e-10 x: [1.00001481 1.00002828]
# Method: Powell , success: True , minimum: 2.391234618951192e-30 x: [1. 1.]
# Method: CG , success: True , minimum: 1.6486281937428067e-11 x: [0.99999426 0.99998864]
# Method: BFGS , success: True , minimum: 4.9931043527025166e-15 x: [0.99999991 0.99999979]
# Method: L-BFGS-B , success: True , minimum: 3.7328852106324297e-13 x: [1.00000053 1.00000057]
# Method: TNC , success: True , minimum: 7.014903400494414e-08 x: [0.99962707 0.99922957]
# Method: COBYLA , success: True , minimum: 1.7339665207898726e-06 x: [0.99835934 0.99609841]
# Method: SLSQP , success: True , minimum: 9.926858237392154e-08 x: [1.00003255 0.99975088]

# %% [markdown]
# # Visualizations
#
# See:
# - https://ax.dev/tutorials/visualizations.html

# %%
from ax.utils.notebook.plotting import render, init_notebook_plotting
from ax.plot.contour import plot_contour

render(plot_contour(model=model, param_x="x1", param_y="x2", metric_name='objective'))
# Out:
# <div>
#
#
#             <div id="32c65b65-d743-4171-a5d2-1b7b9919cf63" class="plotly-graph-div" style="height:450px; width:950px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("
259622064850245, 26.12074535811224, 24.91853471462738, 23.663739888801736, 22.368729180390407, 21.047200204217578, 19.713819487167793, 18.383813369925893, 17.072529044207137, 15.794979013985516, 14.565377614024989, 13.39667626399043, 12.300106102363397, 11.284743536131458, 10.357126402186243, 9.520963665897966, 8.776992584149642, 8.123032524909487, 7.554257372522503, 7.063667289902963, 6.642705654870445, 6.281951825193049, ...

# %%
from ax.plot.contour import interact_contour

render(interact_contour(model=model, metric_name='objective'))
# Out:
# <div>
#
#
#             <div id="0889bff2-b7b3-4db0-b372-590e1fdb918c" class="plotly-graph-div" style="height:450px; width:950px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0889bff2-b7b3-4db0-b372-590e1fdb918c")) {
#                     Plotly.newPlot(
#                         '0889bff2-b7b3-4db0-b372-590e1fdb918c',
#                         [{"autocolorscale": false, "autocontour": true, "colorbar": {"len": 0.875, "tickfont": {"size": 8}, "ticksuffix": "", "x": 0.45, "y": 0.5}, "colorscale": [[0.0, "rgb(247,252,253)"], [0.125, "rgb(229,245,249)"], [0.25, "rgb(204,236,230)"], [0.375, "rgb(153,216,201)"], [0.5, "rgb(102,194,164)"], [0.625, "rgb(65,174,118)"], [0.75, "rgb(35,139,69)"], [0.875, "rgb(0,109,44)"], [1.0, "rgb(0,68,27)"]], "contours": {"coloring": "heatmap"}, "hoverinfo": "x+y+z", "ncontours": 25, "type": "contour", "visible": false, "x": [-2.0, -1.9387755102040816, -1.8775510204081634, -1.816326530612245, -1.7551020408163265, -1.693877551020408, -1.6326530612244898, -1.5714285714285714, -1.510204081632653, -1.4489795918367347, -1.3877551020408163, -1.3265306122448979, -1.2653061224489797, -1.2040816326530612, -1.1428571428571428, -1.0816326530612246, -1.0204081632653061, -0.9591836734693877, -0.8979591836734695, -0.8367346938775511, -0.7755102040816326, -0.7142857142857144, -0.653061224489796, -0.5918367346938775, -0.5306122448979593, -0.4693877551020409, -0.40816326530612246, -0.346938775510204, -0.2857142857142858, -0.22448979591836737, -0.16326530612244894, -0.10204081632653073, -0.04081632653061229, 0.020408163265305923, 0.08163265306122458, 0.1428571428571428, 0.204081632653061, 0.26530612244897966, 0.3265306122448979, 0.3877551020408161, 0.44897959183673475, 0.510204081632653, 0.5714285714285712, 0.6326530612244898, 0.693877551020408, 0.7551020408163263, 0.8163265306122449, 0.8775510204081631, 0.9387755102040813, 1.0], "xaxis": "x", "y": [-2.0, -1.9387755102040816, -1.8775510204081634, -1.816326530612245, -1.7551020408163265, -1.693877551020408, -1.6326530612244898, -1.5714285714285714, -1.510204081632653, -1.4489795918367347, -1.3877551020408163, -1.3265306122448979, -1.2653061224489797, -1.2040816326530612, -1.1428571428571428, -1.0816326530612246, -1.0204081632653061, -0.9591836734693877, -0.8979591836734695, -0.8367346938775511, -0.7755102040816326, -0.7142857142857144, -0.653061224489796, -0.5918367346938775, -0.5306122448979593, -0.4693877551020409, -0.40816326530612246, -0.346938775510204, -0.2857142857142858, -0.22448979591836737, -0.16326530612244894, -0.10204081632653073, -0.04081632653061229, 0.020408163265305923, 0.08163265306122458, 0.1428571428571428, 0.204081632653061, 0.26530612244897966, 0.3265306122448979, 0.3877551020408161, 0.44897959183673475, 0.510204081632653, 0.5714285714285712, 0.6326530612244898, 0.693877551020408, 0.7551020408163263, 0.8163265306122449, 0.8775510204081631, 0.9387755102040813, 1.0], "yaxis": "y", "z": [[18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726, 18.71218326309726], [17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.778031650070094, 17.7780316500 ...
